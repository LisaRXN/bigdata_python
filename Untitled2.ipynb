# %% [markdown]
# <a href="https://colab.research.google.com/github/LisaRXN/bigdata_python/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Etape 1 : Importation des données

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option('display.max_columns', None)
sns.set(style="whitegrid")

# Chargement des fichiers
orders = pd.read_csv('orders.csv')
products = pd.read_csv('products.csv')
aisles = pd.read_csv('aisles.csv')
departments = pd.read_csv('departments.csv')
order_products = pd.read_csv('order_products.csv')

datasets = {
    "orders": orders,
    "products": products,
    "aisles": aisles,
    "departments": departments,
    "order_products": order_products
}

# Apperçu des fichiers
for name, data in datasets.items():
    print(f"\n{name.capitalize()} dataset:")
    display(data.head(4))
# Out:
# Orders dataset:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# Products dataset:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
#
#    department_id
# 0             19
# 1             13
# 2              7
# 3              1
# Aisles dataset:
#    aisle_id                  aisle
# 0         1  prepared soups salads
# 1         2      specialty cheeses
# 2         3    energy granola bars
# 3         4          instant foods
# Departments dataset:
#    department_id department
# 0              1     frozen
# 1              2      other
# 2              3     bakery
# 3              4    produce
# Order_products dataset:
#    order_id  product_id  add_to_cart_order  reordered
# 0         2       33120                  1          1
# 1         2       28985                  2          1
# 2         2        9327                  3          0
# 3         2       45918                  4          1

# %%
# Vérification des valeurs nulles et des doublons
for name, data in datasets.items():
    print(f"\n{name.capitalize()} dataset:")

    # Vérifier les valeurs nulles
    null_counts = data.isnull().sum()
    print("Valeurs nulles par colonne :")
    print(null_counts[null_counts > 0])  # Affiche uniquement les colonnes avec des valeurs nulles

    # Vérifier les doublons
    duplicate_count = data.duplicated().sum()
    print(f"Nombre de doublons : {duplicate_count}")

    print("-" * 40)
# Out:
# Orders dataset:
# Valeurs nulles par colonne :
# days_since_prior_order    206209
# dtype: int64
# Nombre de doublons : 0
# ----------------------------------------
#
# Products dataset:
# Valeurs nulles par colonne :
# Series([], dtype: int64)
# Nombre de doublons : 0
# ----------------------------------------
#
# Aisles dataset:
# Valeurs nulles par colonne :
# Series([], dtype: int64)
# Nombre de doublons : 0
# ----------------------------------------
#
# Departments dataset:
# Valeurs nulles par colonne :
# Series([], dtype: int64)
# Nombre de doublons : 0
# ----------------------------------------
#
# Order_products dataset:
# Valeurs nulles par colonne :
# reordered    1
# dtype: int64
# Nombre de doublons : 0
# ----------------------------------------

# %%
print("Suppressions des lignes avec des valeurs nulles.")
datasets["order_products"].dropna(subset=['reordered'], inplace=True)
# Out:
# Lignes avec des valeurs nulles supprimées.

# %% [markdown]
# # Etape 2 : Analyse des données

# %% [markdown]
# Nombre total d'achats

# %%
# Calcul du nombre total d'achats pour tous les produits (achat + réachat)
total_achats = orders['order_id'].count()

print(f"Le nombre total d'achats : {total_achats}")


# Calcul du nombre total de réachats
total_reachats = order_products[order_products['reordered'] == 1].groupby('order_id')['product_id'].nunique().count()
print(f"Le nombre total de réachats est : {total_reachats}")
# Out:
# Le nombre total d'achats : 3421083
# Le nombre total de réachats est : 2826361

# %% [markdown]
# 1. Produits les plus achetés (total des achats)

# %%
# Nombre total d'achats
display( orders['order_number'].sum() )

# Nombre total de fois qu'un produit a été acheté
product_counts = order_products.groupby('product_id').size().reset_index(name='order_count')

# Merge avec la table "products" pour obtenir les noms des produits
product_counts_merged = product_counts.merge(products, on='product_id')

# Trier par le nombre d'achats
top_products = product_counts_merged.sort_values(by='order_count', ascending=False).head(10)

print("\nTop 10 des produits les plus achetés (tous achats confondus) :")
display(top_products[['product_name', 'order_count']])
# Out:
# 58688193
# Top 10 des produits les plus achetés (tous achats confondus) :
#                  product_name  order_count
# 24848                  Banana       472565
# 13172  Bag of Organic Bananas       379450
# 21133    Organic Strawberries       264683
# 21899    Organic Baby Spinach       241921
# 47198    Organic Hass Avocado       213584
# 47755         Organic Avocado       176815
# 47615             Large Lemon       152657
# 16793            Strawberries       142951
# 26204                   Limes       140627
# 27839      Organic Whole Milk       137905

# %% [markdown]
# 2. Produits les plus réachetés

# %%
# Filtrer les produits réachetés (reordered = 1)
reordered_counts = order_products[order_products['reordered'] == 1].groupby('product_id').size().reset_index(name='reordered_count')

# Fusionner avec le dataset "products" pour obtenir les noms des produits
reordered_counts_merged = reordered_counts.merge(products, on='product_id')

# Trier par le nombre de réachats
top_reordered_products = reordered_counts_merged.sort_values(by='reordered_count', ascending=False).head(10)

# Calcul des pourcentages de réachat de chaque produit
reorder_pourcent = top_reordered_products['reordered_count'] * 100 / total_reachats
top_reordered_products['pourcent'] = reorder_pourcent.round(1)

print("\nTop 10 des produits réachetés :")
display(top_reordered_products[['product_name', 'reordered_count', 'pourcent']])
# Out:
# Top 10 des produits réachetés :
#                  product_name  reordered_count  pourcent
# 22680                  Banana           398609      14.1
# 11997  Bag of Organic Bananas           315913      11.2
# 19282    Organic Strawberries           205845       7.3
# 19973    Organic Baby Spinach           186884       6.6
# 43048    Organic Hass Avocado           170131       6.0
# 43552         Organic Avocado           134044       4.7
# 25420      Organic Whole Milk           114510       4.1
# 43429             Large Lemon           106255       3.8
# 25530     Organic Raspberries           105409       3.7
# 15321            Strawberries            99802       3.5

# %% [markdown]
# 3. Départements et allées générant le plus de ventes

# %%
# Lier les produits aux départements
product_departments = products.merge(departments, on='department_id')

# Calculer le nombre de produits vendus par département
department_orders = order_products.merge(product_departments, on='product_id').groupby('department').size().reset_index(name='order_count')

# Trier par nombre de ventes
top_departments = department_orders.sort_values(by='order_count', ascending=False).head(10)

print("\nTop des départements les plus vendus :")
display(top_departments[['department', 'order_count']])
# Out:
# Top des départements les plus vendus :
#          department  order_count
# 19          produce      7674274
# 7        dairy eggs      4383700
# 20           snacks      2338197
# 3         beverages      2178286
# 10           frozen      1810007
# 16           pantry      1518065
# 2            bakery       952427
# 6      canned goods       864368
# 8              deli       851400
# 9   dry goods pasta       701552

# %%
# Lier les produits aux rayons
product_aisles = products.merge(aisles, on='aisle_id')

# Calculer le nombre de produits vendus par rayon
aisle_orders = order_products.merge(product_aisles, on='product_id').groupby('aisle').size().reset_index(name='order_count')

# Trier par nombre de ventes
top_aisles = aisle_orders.sort_values(by='order_count', ascending=False).head(10)

print("\nTop des rayons les plus vendus :")
display(top_aisles[['aisle', 'order_count']])
# Out:
# Top des rayons les plus vendus :
#                              aisle  order_count
# 50                    fresh fruits      2949791
# 53                fresh vegetables      2765914
# 98      packaged vegetables fruits      1429404
# 133                         yogurt      1175121
# 93                 packaged cheese       793923
# 83                            milk       721565
# 131  water seltzer sparkling water       681506
# 25                  chips pretzels       585021
# 119                soy lactosefree       516858
# 11                           bread       473538

# %% [markdown]
# 4. Analyse des achats par jour de la semaine et heure de la journée

# %%
# Nombre d'achats par jour de la semaine
daily_orders = orders.groupby('order_dow').size().reset_index(name='order_count')
days = ['Lundi', 'Mardi', 'Mercredi', 'Jeudi', 'Vendredi', 'Samedi', 'Dimanche']

daily_orders['day_name'] = daily_orders['order_dow'].apply(lambda x: days[x])

# Affichage du nombre d'achats par jour de la semaine
print("\nNombre d'achats en fonction du jour de la semaine :")
display(daily_orders)

# Nombre d'achats par heure de la journée (order_hour_of_day)
hourly_orders = orders.groupby('order_hour_of_day').size().reset_index(name='oder_count')

# Affichage du nombre d'achats par heure de la journée
print("\nNombre d'achats en fonction de l'heure de la journée :")
print(hourly_orders)
# Out:
# Nombre d'achats en fonction du jour de la semaine :
#    order_dow  order_count  day_name
# 0          0       600905     Lundi
# 1          1       587478     Mardi
# 2          2       467260  Mercredi
# 5          5       453368    Samedi
# 6          6       448761  Dimanche
# 3          3       436972     Jeudi
# 4          4       426339  Vendredi
# Nombre d'achats en fonction de l'heure de la journée :
#     order_hour_of_day  oder_count
# 0                   0       22758
# 1                   1       12398
# 2                   2        7539
# 3                   3        5474
# 4                   4        5527
# 5                   5        9569
# 6                   6       30529
# 7                   7       91868
# 8                   8      178201
# 9                   9      257812
# 10                 10      288418
# 11                 11      284728
# 12                 12      272841
# 13                 13      277999
# 14                 14      283042
# 15                 15      283639
# 16                 16      272553
# 17                 17      228795
# 18                 18      182912
# 19                 19      140569
# 20                 20      104292
# 21                 21       78109
# 22                 22       61468
# 23                 23       40043

# %% [markdown]
# 5. Visualisation des données

# %%
# Graphique des produits les plus achetés
plt.figure(figsize=(10, 6))
sns.barplot(x='order_count', y='product_name', data=top_products, palette='viridis', hue='order_count')
plt.title('Top 10 des produits les plus achetés')
plt.xlabel('Nombre d\'achats')
plt.ylabel('Nom du produit')
plt.show()

# Graphique des produits les plus achetés
plt.figure(figsize=(10, 6))
sns.barplot(x='reordered_count', y='product_name', data=top_reordered_products, palette='viridis', hue='reordered_count')
plt.title('Top 10 des produits les plus achetés')
plt.xlabel('Nombre d\'achats')
plt.ylabel('Nom du produit')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'reordered_count'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-74-7d8c481b60c1> in <cell line: 19>()
#      17
#      18 # Calcul du total des réachats
# ---> 19 total_reorders = top_products['reordered_count'].sum()
#      20
#      21 # Ajouter une colonne pour le pourcentage des réachats
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4100             if self.columns.nlevels > 1:
#    4101                 return self._getitem_multilevel(key)
# -> 4102             indexer = self.columns.get_loc(key)
#    4103             if is_integer(indexer):
#    4104                 indexer = [indexer]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'reordered_count'
